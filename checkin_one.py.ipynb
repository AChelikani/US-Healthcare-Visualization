# %%
from factual import Factual
import config

# factual = Factual(config.API_KEY, config.API_SECRET)
# data = factual.table('healthcare-providers-us')

abbr_to_state = {}
p = {}
h = {}

with open("state_population.txt") as f:
    for line in f:
        state, abbr, pop = line.rstrip().split(",")
        p[abbr] = int(pop)
        abbr_to_state[abbr] = state

with open("state_healthcare.txt") as f:
    for line in f:
        abbr, health = line.rstrip().split(",")
        h[abbr] = int(health)


# Construct resulting string to plug into https://www.amcharts.com/demos/us-heat-map/#theme-light
res = ""
for state in h:
    density = float(h[state])/p[state]
    res += "{\n id: 'US-" + state + "',\n value: " + str(density) + "}, "

print res
# print set(p.keys()) - set(h.keys())
# Out:
# {
#  id: 'US-WA',
#  value: 0.0058139288284}, {
#  id: 'US-DE',
#  value: 0.00548111281266}, {
#  id: 'US-WI',
#  value: 0.00476650803787}, {
#  id: 'US-WV',
#  value: 0.00410098963472}, {
#  id: 'US-HI',
#  value: 0.00606502318955}, {
#  id: 'US-FL',
#  value: 0.00500839111677}, {
#  id: 'US-AK',
#  value: 0.00527010903894}, {
#  id: 'US-NH',
#  value: 0.00538280899767}, {
#  id: 'US-NJ',
#  value: 0.00512636151337}, {
#  id: 'US-NM',
#  value: 0.00485364306345}, {
#  id: 'US-TX',
#  value: 0.00433938140652}, {
#  id: 'US-LA',
#  value: 0.00379415776679}, {
#  id: 'US-NC',
#  value: 0.00474413157992}, {
#  id: 'US-ND',
#  value: 0.00504048582996}, {
#  id: 'US-NE',
#  value: 0.00454342786585}, {
#  id: 'US-TN',
#  value: 0.00444309063198}, {
#  id: 'US-NY',
#  value: 0.00624368395007}, {
#  id: 'US-PA',
#  value: 0.00562850712976}, {
#  id: 'US-WY',
#  value: 0.00414555411092}, {
#  id: 'US-RI',
#  value: 0.00600103594421}, {
#  id: 'US-NV',
#  value: 0.00460100978002}, {
#  id: 'US-VA',
#  value: 0.00471864508304}, {
#  id: 'US-CO',
#  value: 0.00600893551914}, {
#  id: 'US-CA',
#  value: 0.00520066221756}, {
#  id: 'US-AL',
#  value: 0.00351982190641}, {
#  id: 'US-AR',
#  value: 0.00376225031795}, {
#  id: 'US-VT',
#  value: 0.00578982206768}, {
#  id: 'US-IL',
#  value: 0.00489013343996}, {
#  id: 'US-GA',
#  value: 0.00424298533199}, {
#  id: 'US-IN',
#  value: 0.00396366408272}, {
#  id: 'US-IA',
#  value: 0.00427738008505}, {
#  id: 'US-OK',
#  value: 0.00404329150358}, {
#  id: 'US-AZ',
#  value: 0.00521768078475}, {
#  id: 'US-ID',
#  value: 0.00415702888745}, {
#  id: 'US-CT',
#  value: 0.00599988548156}, {
#  id: 'US-ME',
#  value: 0.00533757724976}, {
#  id: 'US-MD',
#  value: 0.00598679954974}, {
#  id: 'US-MA',
#  value: 0.00767935975777}, {
#  id: 'US-OH',
#  value: 0.00465968005327}, {
#  id: 'US-UT',
#  value: 0.00469422600797}, {
#  id: 'US-MO',
#  value: 0.00481679779368}, {
#  id: 'US-MN',
#  value: 0.00578313272605}, {
#  id: 'US-MI',
#  value: 0.00505079064691}, {
#  id: 'US-KS',
#  value: 0.00433972693234}, {
#  id: 'US-MT',
#  value: 0.00450346100344}, {
#  id: 'US-MS',
#  value: 0.00306293410315}, {
#  id: 'US-SC',
#  value: 0.00424973803668}, {
#  id: 'US-KY',
#  value: 0.00418974958737}, {
#  id: 'US-OR',
#  value: 0.00587186703451}, {
#  id: 'US-SD',
#  value: 0.00465659129568},
